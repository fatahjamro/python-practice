# %%
# Random Number in Numpy
# Pseudo Random and True random number.
# from numpy import random 

from numpy import random

x = random.randint(100) # Random number between 0 and 100
print(x)
# Out:
# 22

# %%
# Generate Random Float

x = random.rand() # Random float between 0 and 1
y = random.rand(2) 

print(x)
print(y)
# Out:
# 0.09123398907278257
# [0.23741557 0.14513231]

# %%
# Five random integer between 0 and 50 in 1-D array
x = random.randint(50, size= (5))
print(x)
# Out:
# [ 9 11 34 49 23]

# %%
#2-D array of random numbers
x = random.randint(50, size = (3,4))
print(x)
# Out:
# [[ 9 40 28 25]
#  [14 29 36 31]
#  [31 44 46  3]]

# %%
# random floats 

x = random.rand(3) # 1-D array

print(x)
# Out:
# [0.22792789 0.77844404 0.30329784]

# %%
y = random.rand(3,4) # 2-D array
print(y)
# Out:
# [[1.12437757e-01 8.55509511e-01 4.59294269e-01 9.97908560e-01]
#  [8.60388790e-01 2.88072631e-01 5.58053421e-01 5.66748891e-04]
#  [1.93925741e-01 2.18002372e-02 8.26122575e-01 8.70962082e-01]]

# %%
# generate random number from array

x= random.choice([3,2,9,5,10,8])
print(x)
# Out:
# 2

# %%
# choice for 2-D array

x = random.choice([2,3,4,5,6,7], size = (3,3))
print(x)
# Out:
# [[6 7 6]
#  [3 7 3]
#  [5 6 6]]

# %%
y = random.choice([2,3,4,5,6,7], size = (2,3))
print(y)
# Out:
# [[6 6 2]
#  [4 5 2]]

# %%
# Random Data distribution

x = random.choice([2,9,4,5,6], p=[0.1, 0.45, 0.1, 0.10,0.25], size = (5))
print(x)
# Out:
# [5 4 9 9 9]

# %%
x = random.choice([2,9,4,5,6], p=[0.1, 0.45, 0.1, 0.10,0.25], size = (3,4))
print(x)
# Out:
# [[6 2 9 9]
#  [9 9 9 6]
#  [9 9 9 4]]

# %%
#Random Permutations

# The numpy module have two methods for permutation, shuffle() and permutation().
# Shuffle means changing the position of the elements of the original array.
# Permutation means giving a permuted sequence of the array but original remains same.

import numpy as np
arr1 = np.array([2,4,5,6])

random.shuffle(arr1)

print(arr1)
print( "using while loop as below: " )
i = 0
while i <6:
  random.shuffle(arr1)
  print(arr1)
  i+=1
# Out:
# [6 2 4 5]
# using while loop as below:
# [2 6 4 5]
# [5 6 2 4]
# [5 6 2 4]
# [4 5 6 2]
# [4 2 5 6]
# [6 5 2 4]

# %%
arr_2 = np.array([9,8,7,6])

x = random.permutation(arr_2)
print(x)
# Out:
# [9 8 6 7]

# %%
n = len(arr_2)
for i in range(n):
  i = random.permutation(arr_2)
  print(i)
# Out:
# [9 7 6 8]
# [6 9 8 7]
# [6 8 7 9]
# [7 6 8 9]

# %%
# if n = n factorial.

N  = (4*3*2*1)
print("n factorial = ",N)

for i in range(N):
  i = random.permutation(arr_2)
  print(i)
# Out:
# n factorial =  24
# [8 6 7 9]
# [8 9 7 6]
# [9 7 8 6]
# [7 9 8 6]
# [6 8 9 7]
# [7 6 8 9]
# [8 9 6 7]
# [8 7 9 6]
# [9 7 6 8]
# [8 6 9 7]
# [6 8 9 7]
# [8 7 9 6]
# [7 9 8 6]
# [8 7 6 9]
# [7 9 8 6]
# [7 6 9 8]
# [8 7 9 6]
# [8 9 7 6]
# [6 7 9 8]
# [9 8 7 6]
# [8 7 6 9]
# [6 9 7 8]
# [7 6 8 9]
# [6 7 9 8]

# %%
# visualize Distributions with Seaborn
# seaborn is a library, using matplotlib under the hood for plotting graphs.
#if you have already installed seaborn, check using 'pip show seaborn'
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0,1,2,3,4,5])

plt.show()
# Out:
# /var/folders/yy/q9gk3w_957913dhpv652znlm0000gn/T/ipykernel_4848/4164320744.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])

# %%
sns.displot([0,1,2,3,4,5])
plt.show()

# %%
sns.distplot([0,1,2,3,4,5], hist=False)

plt.show()
# Out:
# /var/folders/yy/q9gk3w_957913dhpv652znlm0000gn/T/ipykernel_4848/3913993784.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5], hist=False)

# %%
sns.kdeplot([0,1,2,3,4,5])
plt.show()

# %%
sns.kdeplot([-5,2,3,4,5,4,2], color='b', shade=True)
plt.show()
# Out:
# /var/folders/yy/q9gk3w_957913dhpv652znlm0000gn/T/ipykernel_4848/2423499454.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot([-5,2,3,4,5,4,2], color='b', shade=True)

# %%
sns.kdeplot([-5,2,3,4,5,4,2], color='b', fill=True, label = 'Fill')
plt.show()

# %% [markdown]
# # Normal Gaussian Distribution
# '''The Normal Distribution is one of the most important distributions.
#
# It is also called the Gaussian Distribution after the German mathematician Carl Friedrich Gauss.
#
# It fits the probability distribution of many events, eg. IQ Scores, Heartbeat etc.
#
# Use the random.normal() method to get a Normal Data Distribution.
#
# It has three parameters:
#
# loc - (Mean) where the peak of the bell exists.
#
# scale - (Standard Deviation) how flat the graph distribution should be.
#
# size - The shape of the returned array.'''

# %%
# Generate a random normal distribution of size 2*3

x = random.normal(size = (2,3))

print(x)
# Out:
# [[ 0.23525155 -0.23050008 -0.34061959]
#  [ 0.61948617 -0.61227708  1.85585252]]

# %%
# generate a random distribution of 2*3 with mean at 2 and standard deviation of 1

x = random.normal(loc =2, scale = 1 , size = (2,3))

print(x)
# Out:
# [[3.17856075 1.57244406 0.22964994]
#  [3.17906386 2.11116858 2.67193394]]

# %%
sns.kdeplot(random.normal(size= 1000))

plt.show()

# %%
sns.kdeplot(random.normal(loc=500,scale=100, size =(1000)))

plt.show()

# %%
sns.kdeplot(random.normal(loc= 50, scale = 10, size= (3,4)))

plt.show()

# %% [markdown]
# ## Binomial Distribution
# Binomial Distribution is a Discrete Distribution.
#
# It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails.
#
# It has three parameters:
#
# n - number of trials.
#
# p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each).
#
# size - The shape of the returned array.

# %%
x = random.binomial(n=10, p=0.5, size= 10)

print(x)
# Out:
# [5 2 8 8 2 5 5 2 6 5]

# %%
#Visualizations of Binomial Distribution

sns.kdeplot(random.binomial(n=10, p=0.5, size=10))

plt.show()

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
plt.show()
# Out:
# /var/folders/yy/q9gk3w_957913dhpv652znlm0000gn/T/ipykernel_4848/2410585992.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

# %%
sns.distplot(random.normal(loc=50, scale = 5, size = 1000), hist =False, kde= True, label = 'Normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, kde=True, label='Binomial')
plt.show()
# Out:
# /var/folders/yy/q9gk3w_957913dhpv652znlm0000gn/T/ipykernel_4848/2242085827.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale = 5, size = 1000), hist =False, kde= True, label = 'Normal')
# /var/folders/yy/q9gk3w_957913dhpv652znlm0000gn/T/ipykernel_4848/2242085827.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# ...

# %%
sns.kdeplot(random.normal(loc=50, scale = 5, size = 1000),   label = 'Normal')
sns.kdeplot(random.binomial(n=100, p=0.5, size=1000), label='Binomial')
plt.show()
